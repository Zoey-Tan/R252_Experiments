# %%
import os

# Check if the notebook is running on Colab
if 'COLAB_GPU' in os.environ:
    # This block will run only in Google Colab
    IN_COLAB = True
    print("Running on Google Colab. Cloning the repository.")
else:
    # This block will run if not in Google Colab
    IN_COLAB = False
    print("Not running on Google Colab. Assuming local environment.")

if IN_COLAB:
    from google.colab import files, drive
    drive.mount('/content/drive')

DRIVE_PATH = '/content/drive/My Drive/resnet18_slt_models/init_signed_constant/' if IN_COLAB else './'
# Out:
# Running on Google Colab. Cloning the repository.
# Mounted at /content/drive

# %%
# %pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.16.4-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 17.6 MB/s eta 0:00:00
# Collecting loss-landscapes
#   Downloading loss_landscapes-3.0.6-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.41.0-py2.py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.8/258.8 kB 21.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from loss-landscapes) (1.25.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, loss-landscapes, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.42 docker-pycreds-0.4.0 gitdb-4.0.11 loss-landscapes-3.0.6 sentry-sdk-1.41.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.4

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# Aborted!
# Exception ignored in atexit callback: <function _Manager._atexit_setup.<locals>.<lambda> at 0x7c3f4989dab0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_manager.py", line 156, in <lambda>
#     self._atexit_lambda = lambda: self._atexit_teardown()
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_manager.py", line 165, in _atexit_teardown
#     self._teardown(exit_code)
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_manager.py", line 176, in _teardown
#     result = self._service.join()
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/service/service.py", line 263, in join
#     ret = self._internal_proc.wait()
#   File "/usr/lib/python3.10/subprocess.py", line 1209, in wait
#     return self._wait(timeout=timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1959, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/usr/lib/python3.10/subprocess.py", line 1917, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt:

# %%
import math
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import CosineAnnealingLR
import torch.autograd as autograd
# import wandb

# %%
class StatisticsTracker:
    instance = None

    def __new__(cls):
        if cls.instance is None:
            cls.instance = super(StatisticsTracker, cls).__new__(cls)
            cls.zero_percentage = 0
            cls.one_percentage = 0
        return cls.instance

    def update(self, zeros, ones, total):
        self.zero_percentage = (zeros / total) * 100
        self.one_percentage = (ones / total) * 100

    def get_statistics(self):
        return self.zero_percentage, self.one_percentage


class GetSubnet(autograd.Function):
    @staticmethod
    def forward(ctx, scores, k):
        # Get the subnetwork by sorting the scores and using the top k%
        out = scores.clone()
        _, idx = scores.flatten().sort()
        j = int((1 - k) * scores.numel())

        # flat_out and out access the same memory.
        flat_out = out.flatten()
        flat_out[idx[:j]] = 0
        flat_out[idx[j:]] = 1

        # print("\n--------------")
        # print("J: ", j)
        # print("bottom: ", len(flat_out[idx[:j]]))
        # print("top: ", len(flat_out[idx[j:]]))
        # print("total: ", len(flat_out))
        # print("total2: ", len(flat_out[idx]))

        # Update statistics
        tracker = StatisticsTracker()
        zeros = (flat_out == 0).sum().item()
        ones = (flat_out == 1).sum().item()
        total = flat_out.numel()
        tracker.update(zeros, ones, total)

        return out

    @staticmethod
    def backward(ctx, g):
        # send the gradient g straight-through on the backward pass.
        return g, None

class NonAffineBatchNorm(nn.BatchNorm2d):
    def __init__(self, dim):
        super(NonAffineBatchNorm, self).__init__(dim, affine=False)

class SubnetConv(nn.Conv2d):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        self.scores = nn.Parameter(torch.Tensor(self.weight.size()))
        nn.init.kaiming_uniform_(self.scores, a=math.sqrt(5))
        self.prune_rate = prune_rate

    def set_prune_rate(self, prune_rate):
        self.prune_rate = prune_rate

    @property
    def clamped_scores(self):
        return self.scores.abs()

    def forward(self, x):
        subnet = GetSubnet.apply(self.clamped_scores, self.prune_rate)
        w = self.weight * subnet

        # # Add check here
        # alive_weights = w.nonzero().size(0)  # Count non-zero elements in w
        # total_weights = w.numel()  # Total number of elements in w
        # percentage_alive = (alive_weights / total_weights) * 100
        # print(f"Percentage of alive weights: {percentage_alive:.2f}%")

        x = F.conv2d(
            x, w, self.bias, self.stride, self.padding, self.dilation, self.groups
        )
        return x

# %%
batch_size = 256
test_batch_size = 1000
epochs = 200
lr = 0.1
momentum = 0.9
weight_decay = 0.0005
nesterov=False
log_interval = 10
data_path = "data"
prune_rate = 0.3
# prune_rate=0.025
save_model = True
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
last_layer_dense = True
num_class = 10
nonlinearity = "relu"
# init = "kaiming_normal"
init = "signed_constant"
mode = "fan_in"
scale_fan = False
conv_type = SubnetConv
bn_type = NonAffineBatchNorm
first_layer_type = None
first_layer_dense = True
gpu = None

# %%
# train_loader = torch.utils.data.DataLoader(datasets.MNIST(os.path.join(data_path, 'mnist'), train=True, download=True,
#                                                           transform=transforms.Compose([transforms.ToTensor(),
#                                                                                         transforms.Normalize((0.1307,), (0.3081,))])),
#                                            batch_size=batch_size, shuffle=True)

# test_loader = torch.utils.data.DataLoader(datasets.MNIST(os.path.join(data_path, 'mnist'), train=False,
#                                                          transform=transforms.Compose([transforms.ToTensor(),
#                                                                                        transforms.Normalize((0.1307,), (0.3081,))])),
#                                           batch_size=test_batch_size, shuffle=True)


normalize = transforms.Normalize(
            mean=[0.491, 0.482, 0.447], std=[0.247, 0.243, 0.262]
        )


train_set = datasets.CIFAR10(root=os.path.join(data_path, 'cifar10'),
                             train=True,
                             download=True,
                             transform=transforms.Compose(
                                                        [
                                                            transforms.RandomCrop(32, padding=4),
                                                            transforms.RandomHorizontalFlip(),
                                                            transforms.ToTensor(),
                                                            normalize,
                                                        ]
                                                    ))
test_set = datasets.CIFAR10(root=os.path.join(data_path, 'cifar10'),
                            train=False,
                            download=True,
                            transform=transforms.Compose([transforms.ToTensor(), normalize]))

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=2, pin_memory=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=test_batch_size, shuffle=False, drop_last=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar10/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:07<00:00, 24256503.96it/s]
# Extracting data/cifar10/cifar-10-python.tar.gz to data/cifar10
# Files already downloaded and verified

# %%
class Builder(object):
    def __init__(self, conv_layer, bn_layer, first_layer=None):
        self.conv_layer = conv_layer
        self.bn_layer = bn_layer
        self.first_layer = first_layer or conv_layer


    def conv(self, kernel_size, in_planes, out_planes, stride=1, first_layer=False):
        conv_layer = self.first_layer if first_layer else self.conv_layer

        if first_layer:
            print(f"==> Building first layer with {str(self.first_layer)}")

        if kernel_size == 3:
            conv = conv_layer(
                in_planes,
                out_planes,
                kernel_size=3,
                stride=stride,
                padding=1,
                bias=False,
            )
        elif kernel_size == 1:
            conv = conv_layer(
                in_planes, out_planes, kernel_size=1, stride=stride, bias=False
            )
        elif kernel_size == 5:
            conv = conv_layer(
                in_planes,
                out_planes,
                kernel_size=5,
                stride=stride,
                padding=2,
                bias=False,
            )
        elif kernel_size == 7:
            conv = conv_layer(
                in_planes,
                out_planes,
                kernel_size=7,
                stride=stride,
                padding=3,
                bias=False,
            )
        else:
            return None

        self._init_conv(conv)

        return conv


    def conv3x3(self, in_planes, out_planes, stride=1, first_layer=False):
        """3x3 convolution with padding"""
        c = self.conv(3, in_planes, out_planes, stride=stride, first_layer=first_layer)
        return c

    def conv1x1(self, in_planes, out_planes, stride=1, first_layer=False):
        """1x1 convolution with padding"""
        c = self.conv(1, in_planes, out_planes, stride=stride, first_layer=first_layer)
        return c

    def conv7x7(self, in_planes, out_planes, stride=1, first_layer=False):
        """7x7 convolution with padding"""
        c = self.conv(7, in_planes, out_planes, stride=stride, first_layer=first_layer)
        return c

    def conv5x5(self, in_planes, out_planes, stride=1, first_layer=False):
        """5x5 convolution with padding"""
        c = self.conv(5, in_planes, out_planes, stride=stride, first_layer=first_layer)
        return c

    def batchnorm(self, planes, last_bn=False, first_layer=False):
        return self.bn_layer(planes)

    def activation(self):
        if nonlinearity == "relu":
            return (lambda: nn.ReLU(inplace=True))()
        else:
            raise ValueError(f"{nonlinearity} is not an initialization option!")

    def _init_conv(self, conv):
        if init == "signed_constant":

            fan = nn.init._calculate_correct_fan(conv.weight, mode)
            if scale_fan:
                fan = fan * (1 - prune_rate)
            gain = nn.init.calculate_gain(nonlinearity)
            std = gain / math.sqrt(fan)
            conv.weight.data = conv.weight.data.sign() * std

        elif init == "unsigned_constant":

            fan = nn.init._calculate_correct_fan(conv.weight, mode)
            if scale_fan:
                fan = fan * (1 - prune_rate)

            gain = nn.init.calculate_gain(nonlinearity)
            std = gain / math.sqrt(fan)
            conv.weight.data = torch.ones_like(conv.weight.data) * std

        elif init == "kaiming_normal":

            if scale_fan:
                fan = nn.init._calculate_correct_fan(conv.weight, mode)
                fan = fan * (1 - prune_rate)
                gain = nn.init.calculate_gain(nonlinearity)
                std = gain / math.sqrt(fan)
                with torch.no_grad():
                    conv.weight.data.normal_(0, std)
            else:
                nn.init.kaiming_normal_(
                    conv.weight, mode=mode, nonlinearity=nonlinearity
                )

        elif init == "kaiming_uniform":
            nn.init.kaiming_uniform_(
                conv.weight, mode=mode, nonlinearity=nonlinearity
            )
        elif init == "xavier_normal":
            nn.init.xavier_normal_(conv.weight)
        elif init == "xavier_constant":

            fan_in, fan_out = nn.init._calculate_fan_in_and_fan_out(conv.weight)
            std = math.sqrt(2.0 / float(fan_in + fan_out))
            conv.weight.data = conv.weight.data.sign() * std

        elif init == "standard":

            nn.init.kaiming_uniform_(conv.weight, a=math.sqrt(5))

        else:
            raise ValueError(f"{init} is not an initialization option!")


def get_builder():

    print("==> Conv Type: {}".format(conv_type))
    print("==> BN Type: {}".format(bn_type))

    #conv_layer = getattr(utils.conv_type, conv_type)
    #bn_layer = getattr(utils.bn_type, bn_type)
    conv_layer = conv_type
    bn_layer = bn_type

    if first_layer_type is not None:
        first_layer = getattr(conv_type, first_layer_type)
        print(f"==> First Layer Type: {first_layer_type}")
    else:
        first_layer = None

    builder = Builder(conv_layer=conv_layer, bn_layer=bn_layer, first_layer=first_layer)
    #builder = Builder(conv_layer=None, bn_layer=None, first_layer=None)

    return builder

# %%
class BasicBlockCIFAR(nn.Module):
    expansion = 1

    def __init__(self, builder, in_planes, planes, stride=1):
        super(BasicBlockCIFAR, self).__init__()
        self.conv1 = builder.conv3x3(in_planes, planes, stride=stride)
        self.bn1 = builder.batchnorm(planes)
        self.conv2 = builder.conv3x3(planes, planes, stride=1)
        self.bn2 = builder.batchnorm(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                builder.conv1x1(in_planes, self.expansion * planes, stride=stride),
                builder.batchnorm(self.expansion * planes),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class BottleneckCIFAR(nn.Module):
    expansion = 4

    def __init__(self, builder, in_planes, planes, stride=1):
        super(BottleneckCIFAR, self).__init__()
        self.conv1 = builder.conv1x1(in_planes, planes)
        self.bn1 = builder.batchnorm(planes)
        self.conv2 = builder.conv3x3(planes, planes, stride=stride)
        self.bn2 = builder.batchnorm(planes)
        self.conv3 = builder.conv1x1(planes, self.expansion * planes)
        self.bn3 = builder.batchnorm(self.expansion * planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                builder.conv1x1(in_planes, self.expansion * planes, stride=stride),
                builder.batchnorm(self.expansion * planes),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)

        return out


class ResNetCIFAR(nn.Module):
    def __init__(self, builder, block, num_blocks):
        super(ResNetCIFAR, self).__init__()
        self.in_planes = 64
        self.builder = builder

        self.conv1 = builder.conv3x3(3, 64, stride=1, first_layer=True)
        self.bn1 = builder.batchnorm(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d(1)

        if last_layer_dense:
            self.fc = nn.Conv2d(512 * block.expansion, 10, 1)
        else:
            self.fc = builder.conv1x1(512 * block.expansion, 10)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.builder, self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = self.fc(out)
        return out.flatten(1)

# %%
import abc
from torch.utils.tensorboard import SummaryWriter

class ProgressMeter(object):
    def __init__(self, num_batches, meters, prefix=""):
        self.batch_fmtstr = self._get_batch_fmtstr(num_batches)
        self.meters = meters
        self.prefix = prefix

    def display(self, batch, tqdm_writer=True):
        entries = [self.prefix + self.batch_fmtstr.format(batch)]
        entries += [str(meter) for meter in self.meters]
        if not tqdm_writer:
            print("\t".join(entries))
        else:
            tqdm.tqdm.write("\t".join(entries))

    def write_to_tensorboard(
        self, writer: SummaryWriter, prefix="train", global_step=None
    ):
        for meter in self.meters:
            avg = meter.avg
            val = meter.val
            if meter.write_val:
                writer.add_scalar(
                    f"{prefix}/{meter.name}_val", val, global_step=global_step
                )

            if meter.write_avg:
                writer.add_scalar(
                    f"{prefix}/{meter.name}_avg", avg, global_step=global_step
                )

    def _get_batch_fmtstr(self, num_batches):
        num_digits = len(str(num_batches // 1))
        fmt = "{:" + str(num_digits) + "d}"
        return "[" + fmt + "/" + fmt.format(num_batches) + "]"

class Meter(object):
    @abc.abstractmethod
    def __init__(self, name, fmt=":f"):
        pass

    @abc.abstractmethod
    def reset(self):
        pass

    @abc.abstractmethod
    def update(self, val, n=1):
        pass

    @abc.abstractmethod
    def __str__(self):
        pass

class AverageMeter(Meter):
    """ Computes and stores the average and current value """

    def __init__(self, name, fmt=":f", write_val=True, write_avg=True):
        self.name = name
        self.fmt = fmt
        self.reset()

        self.write_val = write_val
        self.write_avg = write_avg

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = "{name} {val" + self.fmt + "} ({avg" + self.fmt + "})"
        return fmtstr.format(**self.__dict__)

# %%
import copy

def get_initial_weights(model):
    initial_weights = {}
    for name, param in model.named_parameters():
        if 'weight' in name:  # This checks if the parameter is a weight
            initial_weights[name] = copy.deepcopy(param.data)
    return initial_weights

def get_initial_scores(model):
    initial_scores = {}
    for name, param in model.named_parameters():
        if 'scores' in name:  # This checks if the parameter is a score
            initial_scores[name] = copy.deepcopy(param.data)
    return initial_scores

def check_weights_change(initial_weights, model):
    counter = 0
    for name, param in model.named_parameters():
        if 'weight' in name:  # Again, checking for weights
            initial_weight = initial_weights[name]
            final_weight = param.data
            # Calculate the absolute difference and check if any values are non-zero
            difference = (initial_weight - final_weight).abs().sum().item()
            if difference > 0:
                counter += 1
                # print(f"Weight '{name}' has changed by {difference}.")

    if counter == 0:
        print("No weights changed.")
    else:
        print("Weihts changed!")

# def check_weights_change(initial_weights, model):
#     total_weights = 0
#     changed_weights = 0

#     for name, param in model.named_parameters():
#         if 'weight' in name:  # Focus on weight parameters
#             initial_weight = initial_weights[name]
#             final_weight = param.data

#             # Count the total number of weights
#             total_weights += param.numel()

#             # Calculate the absolute difference
#             difference = (initial_weight - final_weight).abs()

#             # Count how many weights have changed (difference > 0)
#             changed_weights += difference.gt(0).sum().item()

#     if total_weights == 0:
#         print("No weights to check.")
#         return

#     # Calculate the percentage of changed weights
#     percentage_changed = (changed_weights / total_weights) * 100

#     print(f"{changed_weights} out of {total_weights} weights changed ({percentage_changed:.2f}%).")

#     # Optionally, you can return this percentage if you want to use it outside the function
#     return percentage_changed


def check_scores_change(initial_scores, model):
    counter = 0
    for name, param in model.named_parameters():
        if 'scores' in name:  # Checking for scores
            initial_score = initial_scores[name]
            final_score = param.data
            # Calculate the absolute difference and check if any values are non-zero
            difference = (initial_score - final_score).abs().sum().item()
            if difference > 0:
                counter += 1

    if counter == 0:
        print("No scores changed.")
    else:
        print("Scores changed!")

# %%
def freeze_model_weights(model):
    print("=> Freezing model weights")

    for n, m in model.named_modules():
        if hasattr(m, "weight") and m.weight is not None:
            print(f"==> No gradient to {n}.weight")
            m.weight.requires_grad = False
            if m.weight.grad is not None:
                print(f"==> Setting gradient of {n}.weight to None")
                m.weight.grad = None

            if hasattr(m, "bias") and m.bias is not None:
                print(f"==> No gradient to {n}.bias")
                m.bias.requires_grad = False

                if m.bias.grad is not None:
                    print(f"==> Setting gradient of {n}.bias to None")
                    m.bias.grad = None


def freeze_model_subnet(model):
    print("=> Freezing model subnet")

    for n, m in model.named_modules():
        if hasattr(m, "scores"):
            m.scores.requires_grad = False
            print(f"==> No gradient to {n}.scores")
            if m.scores.grad is not None:
                print(f"==> Setting gradient of {n}.scores to None")
                m.scores.grad = None


def unfreeze_model_weights(model):
    print("=> Unfreezing model weights")

    for n, m in model.named_modules():
        if hasattr(m, "weight") and m.weight is not None:
            print(f"==> Gradient to {n}.weight")
            m.weight.requires_grad = True
            if hasattr(m, "bias") and m.bias is not None:
                print(f"==> Gradient to {n}.bias")
                m.bias.requires_grad = True


def unfreeze_model_subnet(model):
    print("=> Unfreezing model subnet")

    for n, m in model.named_modules():
        if hasattr(m, "scores"):
            print(f"==> Gradient to {n}.scores")
            m.scores.requires_grad = True


def set_model_prune_rate(model, prune_rate):
    print(f"==> Setting prune rate of network to {prune_rate}")

    for n, m in model.named_modules():
        if hasattr(m, "set_prune_rate"):
            m.set_prune_rate(prune_rate)
            print(f"==> Setting prune rate of {n} to {prune_rate}")


def get_optimizer(model):
    parameters = list(model.named_parameters())
    bn_params = [v for n, v in parameters if ("bn" in n) and v.requires_grad]
    rest_params = [v for n, v in parameters if ("bn" not in n) and v.requires_grad]
    optimizer = torch.optim.SGD(
        [
            {
                "params": bn_params,
                "weight_decay": weight_decay,
            },
            {"params": rest_params, "weight_decay": weight_decay},
        ],
        lr,
        momentum=momentum,
        weight_decay=weight_decay,
        nesterov=nesterov,
    )

    return optimizer

# %%
def train(model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    running_loss = 0.0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        running_loss += loss.item()

    avg_training_loss = running_loss / len(train_loader)
    # wandb.log({"epoch": epoch+1, "Training Loss": avg_training_loss})


def test(model, device, criterion, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target)
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    # wandb.log({"epoch": epoch+1, "Validation Loss": test_loss})


def modifier(prune_rate, epoch, model):
    if epoch == 0:
        set_model_prune_rate(model, prune_rate=0.0)
        freeze_model_subnet(model)
        unfreeze_model_weights(model)
        return prune_rate

    elif epoch == 6:
        set_model_prune_rate(model, prune_rate=prune_rate)
        unfreeze_model_subnet(model)
        freeze_model_weights(model)
        return prune_rate

    # elif epoch % 5 == 0 and epoch < 50 and epoch > 6:
    #     print("Changed prune rate to ", prune_rate-0.1)
    #     set_model_prune_rate(model, prune_rate=prune_rate-0.1)
    #     return prune_rate-0.1

    # elif epoch == 55:
    #     print("Changing prunning rate to 2.5%")
    #     set_model_prune_rate(model, prune_rate=0.025)
    #     return 0.025

    return prune_rate

# %%
import math

prune_rate = 0.3
# checkpoint_path = os.path.join(DRIVE_PATH, "resnet18_slt_epoch_99_30.pth")
# checkpoint = torch.load(checkpoint_path, map_location=device)
# model = ResNetCIFAR(get_builder(), BasicBlockCIFAR, [2,2,2,2])
# model.load_state_dict(checkpoint['model_state_dict'])

model = ResNetCIFAR(get_builder(), BasicBlockCIFAR, [2,2,2,2])
model.to(device)
initial_weights = get_initial_weights(model)
initial_scores = get_initial_scores(model)

set_model_prune_rate(model, prune_rate=prune_rate)
freeze_model_weights(model)


# optimizer = optim.SGD([p for p in model.parameters() if p.requires_grad],
#                       lr=lr,
#                       momentum=momentum,
#                       weight_decay=weight_decay)

optimizer = get_optimizer(model)
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

criterion = nn.CrossEntropyLoss().to(device)

scheduler = CosineAnnealingLR(optimizer, T_max=epochs)
# scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

curr_prune_rate = prune_rate
for epoch in range(0, epochs):
    print("\n-------------------------------------")
    check_weights_change(initial_weights, model)
    check_scores_change(initial_scores, model)

    curr_prune_rate = modifier(curr_prune_rate, epoch, model)
    train(model, device, train_loader, optimizer, criterion, epoch)

    # compute the percentage of weights used in the forward pass
    tracker = StatisticsTracker()
    zero_percentage, one_percentage = tracker.get_statistics()
    print(f"Percentage of weights set to zero: {zero_percentage}%")
    print(f"Percentage of weights set to one: {one_percentage}%")

    test(model, device, criterion, test_loader)
    scheduler.step()

    one_percent_formated = math.floor(one_percentage)
    if epoch > 6:
        model_save_path = os.path.join(DRIVE_PATH, f"resnet18_slt_epoch_{epoch}_{one_percent_formated}_final.pth")
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
        }, model_save_path)

        print(f"Model saved to {model_save_path} after epoch {epoch}")
# Out:
# ==> Conv Type: <class '__main__.SubnetConv'>
# ==> BN Type: <class '__main__.NonAffineBatchNorm'>
# ==> Building first layer with <class '__main__.SubnetConv'>
# ==> Setting prune rate of network to 0.3
# ==> Setting prune rate of conv1 to 0.3
# ==> Setting prune rate of layer1.0.conv1 to 0.3
# ==> Setting prune rate of layer1.0.conv2 to 0.3
# ==> Setting prune rate of layer1.1.conv1 to 0.3
# ==> Setting prune rate of layer1.1.conv2 to 0.3
# ==> Setting prune rate of layer2.0.conv1 to 0.3
# ==> Setting prune rate of layer2.0.conv2 to 0.3
# ==> Setting prune rate of layer2.0.shortcut.0 to 0.3
# ==> Setting prune rate of layer2.1.conv1 to 0.3
# ==> Setting prune rate of layer2.1.conv2 to 0.3
# ==> Setting prune rate of layer3.0.conv1 to 0.3
# ==> Setting prune rate of layer3.0.conv2 to 0.3
# ==> Setting prune rate of layer3.0.shortcut.0 to 0.3
# ==> Setting prune rate of layer3.1.conv1 to 0.3
# ==> Setting prune rate of layer3.1.conv2 to 0.3
# ==> Setting prune rate of layer4.0.conv1 to 0.3
# ==> Setting prune rate of layer4.0.conv2 to 0.3
# ==> Setting prune rate of layer4.0.shortcut.0 to 0.3
# ==> Setting prune rate of layer4.1.conv1 to 0.3
# ==> Setting prune rate of layer4.1.conv2 to 0.3
# => Freezing model weights
# ==> No gradient to conv1.weight
# ==> No gradient to layer1.0.conv1.weight
# ==> No gradient to layer1.0.conv2.weight
# ==> No gradient to layer1.1.conv1.weight
# ==> No gradient to layer1.1.conv2.weight
# ==> No gradient to layer2.0.conv1.weight
# ==> No gradient to layer2.0.conv2.weight
# ==> No gradient to layer2.0.shortcut.0.weight
# ==> No gradient to layer2.1.conv1.weight
# ==> No gradient to layer2.1.conv2.weight
# ==> No gradient to layer3.0.conv1.weight
# ==> No gradient to layer3.0.conv2.weight
# ==> No gradient to layer3.0.shortcut.0.weight
# ==> No gradient to layer3.1.conv1.weight
# ==> No gradient to layer3.1.conv2.weight
# ==> No gradient to layer4.0.conv1.weight
# ==> No gradient to layer4.0.conv2.weight
# ==> No gradient to layer4.0.shortcut.0.weight
# ==> No gradient to layer4.1.conv1.weight
# ==> No gradient to layer4.1.conv2.weight
# ==> No gradient to fc.weight
# ==> No gradient to fc.bias
#
# -------------------------------------
# No weights changed.
# No scores changed.
# ==> Setting prune rate of network to 0.0
# ==> Setting prune rate of conv1 to 0.0
# ==> Setting prune rate of layer1.0.conv1 to 0.0
# ==> Setting prune rate of layer1.0.conv2 to 0.0
# ==> Setting prune rate of layer1.1.conv1 to 0.0
# ==> Setting prune rate of layer1.1.conv2 to 0.0
# ==> Setting prune rate of layer2.0.conv1 to 0.0
# ==> Setting prune rate of layer2.0.conv2 to 0.0
# ==> Setting prune rate of layer2.0.shortcut.0 to 0.0
# ==> Setting prune rate of layer2.1.conv1 to 0.0
# ==> Setting prune rate of layer2.1.conv2 to 0.0
# ==> Setting prune rate of layer3.0.conv1 to 0.0
# ==> Setting prune rate of layer3.0.conv2 to 0.0
# ==> Setting prune rate of layer3.0.shortcut.0 to 0.0
# ==> Setting prune rate of layer3.1.conv1 to 0.0
# ==> Setting prune rate of layer3.1.conv2 to 0.0
# ==> Setting prune rate of layer4.0.conv1 to 0.0
# ==> Setting prune rate of layer4.0.conv2 to 0.0
# ==> Setting prune rate of layer4.0.shortcut.0 to 0.0
# ==> Setting prune rate of layer4.1.conv1 to 0.0
# ==> Setting prune rate of layer4.1.conv2 to 0.0
# => Freezing model subnet
# ==> No gradient to conv1.scores
# ==> No gradient to layer1.0.conv1.scores
# ==> No gradient to layer1.0.conv2.scores
# ==> No gradient to layer1.1.conv1.scores
# ==> No gradient to layer1.1.conv2.scores
# ==> No gradient to layer2.0.conv1.scores
# ==> No gradient to layer2.0.conv2.scores
# ==> No gradient to layer2.0.shortcut.0.scores
# ==> No gradient to layer2.1.conv1.scores
# ==> No gradient to layer2.1.conv2.scores
# ==> No gradient to layer3.0.conv1.scores
# ==> No gradient to layer3.0.conv2.scores
# ==> No gradient to layer3.0.shortcut.0.scores
# ==> No gradient to layer3.1.conv1.scores
# ==> No gradient to layer3.1.conv2.scores
# ==> No gradient to layer4.0.conv1.scores
# ==> No gradient to layer4.0.conv2.scores
# ==> No gradient to layer4.0.shortcut.0.scores
# ==> No gradient to layer4.1.conv1.scores
# ==> No gradient to layer4.1.conv2.scores
# => Unfreezing model weights
# ==> Gradient to conv1.weight
# ==> Gradient to layer1.0.conv1.weight
# ==> Gradient to layer1.0.conv2.weight
# ==> Gradient to layer1.1.conv1.weight
# ==> Gradient to layer1.1.conv2.weight
# ==> Gradient to layer2.0.conv1.weight
# ==> Gradient to layer2.0.conv2.weight
# ==> Gradient to layer2.0.shortcut.0.weight
# ==> Gradient to layer2.1.conv1.weight
# ==> Gradient to layer2.1.conv2.weight
# ==> Gradient to layer3.0.conv1.weight
# ==> Gradient to layer3.0.conv2.weight
# ==> Gradient to layer3.0.shortcut.0.weight
# ==> Gradient to layer3.1.conv1.weight
# ==> Gradient to layer3.1.conv2.weight
# ==> Gradient to layer4.0.conv1.weight
# ==> Gradient to layer4.0.conv2.weight
# ==> Gradient to layer4.0.shortcut.0.weight
# ==> Gradient to layer4.1.conv1.weight
# ==> Gradient to layer4.1.conv2.weight
# ==> Gradient to fc.weight
# ==> Gradient to fc.bias
# Train Epoch: 0 [0/50000 (0%)]	Loss: 2.302797
# Train Epoch: 0 [25600/50000 (51%)]	Loss: 2.304385
# Percentage of weights set to zero: 100.0%
# Percentage of weights set to one: 0.0%
# Test set: Average loss: 0.0023, Accuracy: 1000/10000 (10%)
#
#
# -------------------------------------
# No weights changed.
# No scores changed.
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.302572
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 2.305343
# Percentage of weights set to zero: 100.0%
# Percentage of weights set to one: 0.0%
# Test set: Average loss: 0.0023, Accuracy: 1000/10000 (10%)
#
#
# -------------------------------------
# No weights changed.
# No scores changed.
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.300313
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 2.302393
# Percentage of weights set to zero: 100.0%
# Percentage of weights set to one: 0.0%
# Test set: Average loss: 0.0023, Accuracy: 1000/10000 (10%)
#
#
# -------------------------------------
# No weights changed.
# No scores changed.
# Train Epoch: 3 [0/50000 (0%)]	Loss: 2.300947
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 2.302790
# Percentage of weights set to zero: 100.0%
# Percentage of weights set to one: 0.0%
# Test set: Average loss: 0.0023, Accuracy: 1000/10000 (10%)
#
#
# -------------------------------------
# No weights changed.
# No scores changed.
# Train Epoch: 4 [0/50000 (0%)]	Loss: 2.302520
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 2.304199
# Percentage of weights set to zero: 100.0%
# Percentage of weights set to one: 0.0%
# Test set: Average loss: 0.0023, Accuracy: 1000/10000 (10%)
#
#
# -------------------------------------
# No weights changed.
# No scores changed.
# Train Epoch: 5 [0/50000 (0%)]	Loss: 2.301602
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 2.301642
# Percentage of weights set to zero: 100.0%
# Percentage of weights set to one: 0.0%
# Test set: Average loss: 0.0023, Accuracy: 1000/10000 (10%)
#
#
# -------------------------------------
# No weights changed.
# No scores changed.
# ==> Setting prune rate of network to 0.3
# ==> Setting prune rate of conv1 to 0.3
# ==> Setting prune rate of layer1.0.conv1 to 0.3
# ==> Setting prune rate of layer1.0.conv2 to 0.3
# ==> Setting prune rate of layer1.1.conv1 to 0.3
# ==> Setting prune rate of layer1.1.conv2 to 0.3
# ==> Setting prune rate of layer2.0.conv1 to 0.3
# ==> Setting prune rate of layer2.0.conv2 to 0.3
# ==> Setting prune rate of layer2.0.shortcut.0 to 0.3
# ==> Setting prune rate of layer2.1.conv1 to 0.3
# ==> Setting prune rate of layer2.1.conv2 to 0.3
# ==> Setting prune rate of layer3.0.conv1 to 0.3
# ==> Setting prune rate of layer3.0.conv2 to 0.3
# ==> Setting prune rate of layer3.0.shortcut.0 to 0.3
# ==> Setting prune rate of layer3.1.conv1 to 0.3
# ==> Setting prune rate of layer3.1.conv2 to 0.3
# ==> Setting prune rate of layer4.0.conv1 to 0.3
# ==> Setting prune rate of layer4.0.conv2 to 0.3
# ==> Setting prune rate of layer4.0.shortcut.0 to 0.3
# ==> Setting prune rate of layer4.1.conv1 to 0.3
# ==> Setting prune rate of layer4.1.conv2 to 0.3
# => Unfreezing model subnet
# ==> Gradient to conv1.scores
# ==> Gradient to layer1.0.conv1.scores
# ==> Gradient to layer1.0.conv2.scores
# ==> Gradient to layer1.1.conv1.scores
# ==> Gradient to layer1.1.conv2.scores
# ==> Gradient to layer2.0.conv1.scores
# ==> Gradient to layer2.0.conv2.scores
# ==> Gradient to layer2.0.shortcut.0.scores
# ==> Gradient to layer2.1.conv1.scores
# ==> Gradient to layer2.1.conv2.scores
# ==> Gradient to layer3.0.conv1.scores
# ==> Gradient to layer3.0.conv2.scores
# ==> Gradient to layer3.0.shortcut.0.scores
# ==> Gradient to layer3.1.conv1.scores
# ==> Gradient to layer3.1.conv2.scores
# ==> Gradient to layer4.0.conv1.scores
# ==> Gradient to layer4.0.conv2.scores
# ==> Gradient to layer4.0.shortcut.0.scores
# ==> Gradient to layer4.1.conv1.scores
# ==> Gradient to layer4.1.conv2.scores
# => Freezing model weights
# ==> No gradient to conv1.weight
# ==> Setting gradient of conv1.weight to None
# ==> No gradient to layer1.0.conv1.weight
# ==> Setting gradient of layer1.0.conv1.weight to None
# ==> No gradient to layer1.0.conv2.weight
# ==> Setting gradient of layer1.0.conv2.weight to None
# ==> No gradient to layer1.1.conv1.weight
# ==> Setting gradient of layer1.1.conv1.weight to None
# ==> No gradient to layer1.1.conv2.weight
# ==> Setting gradient of layer1.1.conv2.weight to None
# ==> No gradient to layer2.0.conv1.weight
# ==> Setting gradient of layer2.0.conv1.weight to None
# ==> No gradient to layer2.0.conv2.weight
# ==> Setting gradient of layer2.0.conv2.weight to None
# ==> No gradient to layer2.0.shortcut.0.weight
# ==> Setting gradient of layer2.0.shortcut.0.weight to None
# ==> No gradient to layer2.1.conv1.weight
# ==> Setting gradient of layer2.1.conv1.weight to None
# ==> No gradient to layer2.1.conv2.weight
# ==> Setting gradient of layer2.1.conv2.weight to None
# ==> No gradient to layer3.0.conv1.weight
# ==> Setting gradient of layer3.0.conv1.weight to None
# ==> No gradient to layer3.0.conv2.weight
# ==> Setting gradient of layer3.0.conv2.weight to None
# ==> No gradient to layer3.0.shortcut.0.weight
# ==> Setting gradient of layer3.0.shortcut.0.weight to None
# ==> No gradient to layer3.1.conv1.weight
# ==> Setting gradient of layer3.1.conv1.weight to None
# ==> No gradient to layer3.1.conv2.weight
# ==> Setting gradient of layer3.1.conv2.weight to None
# ==> No gradient to layer4.0.conv1.weight
# ==> Setting gradient of layer4.0.conv1.weight to None
# ==> No gradient to layer4.0.conv2.weight
# ==> Setting gradient of layer4.0.conv2.weight to None
# ==> No gradient to layer4.0.shortcut.0.weight
# ==> Setting gradient of layer4.0.shortcut.0.weight to None
# ==> No gradient to layer4.1.conv1.weight
# ==> Setting gradient of layer4.1.conv1.weight to None
# ==> No gradient to layer4.1.conv2.weight
# ==> Setting gradient of layer4.1.conv2.weight to None
# ==> No gradient to fc.weight
# ==> Setting gradient of fc.weight to None
# ==> No gradient to fc.bias
# ==> Setting gradient of fc.bias to None
# Train Epoch: 6 [0/50000 (0%)]	Loss: 2.518104
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.612367
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0016, Accuracy: 4318/10000 (43%)
#
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.489733
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.357915
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0014, Accuracy: 5197/10000 (52%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_7_30_final.pth after epoch 7
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.149869
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.131781
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0011, Accuracy: 6249/10000 (62%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_8_30_final.pth after epoch 8
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.031967
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.069972
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0010, Accuracy: 6475/10000 (65%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_9_30_final.pth after epoch 9
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.816140
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.716069
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0008, Accuracy: 6978/10000 (70%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_10_30_final.pth after epoch 10
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.744747
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.578278
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0011, Accuracy: 6377/10000 (64%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_11_30_final.pth after epoch 11
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.682906
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.715025
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7576/10000 (76%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_12_30_final.pth after epoch 12
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.696805
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.602802
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0009, Accuracy: 7240/10000 (72%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_13_30_final.pth after epoch 13
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.522859
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.624764
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 7877/10000 (79%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_14_30_final.pth after epoch 14
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.585865
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.457142
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7744/10000 (77%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_15_30_final.pth after epoch 15
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.469633
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.491209
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7722/10000 (77%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_16_30_final.pth after epoch 16
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.514808
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.440084
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 7954/10000 (80%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_17_30_final.pth after epoch 17
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.395622
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.519817
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8108/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_18_30_final.pth after epoch 18
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.416999
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.476632
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7617/10000 (76%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_19_30_final.pth after epoch 19
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.392982
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.478675
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7787/10000 (78%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_20_30_final.pth after epoch 20
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.385560
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.364740
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8167/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_21_30_final.pth after epoch 21
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.412111
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.335428
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7882/10000 (79%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_22_30_final.pth after epoch 22
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.316779
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.368481
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0009, Accuracy: 7421/10000 (74%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_23_30_final.pth after epoch 23
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.399823
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.267622
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8295/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_24_30_final.pth after epoch 24
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.290404
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.309900
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 7981/10000 (80%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_25_30_final.pth after epoch 25
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.346327
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.322156
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8296/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_26_30_final.pth after epoch 26
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.239793
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.363486
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8163/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_27_30_final.pth after epoch 27
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.379124
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.340861
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7880/10000 (79%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_28_30_final.pth after epoch 28
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.327991
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.481965
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8302/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_29_30_final.pth after epoch 29
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.258406
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.331798
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8252/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_30_30_final.pth after epoch 30
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.343908
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.371276
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8262/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_31_30_final.pth after epoch 31
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.319519
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.325884
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8220/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_32_30_final.pth after epoch 32
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.333401
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.284966
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8358/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_33_30_final.pth after epoch 33
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.293732
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.319768
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8195/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_34_30_final.pth after epoch 34
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.411282
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.354669
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8115/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_35_30_final.pth after epoch 35
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.359532
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.263661
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8140/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_36_30_final.pth after epoch 36
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.282208
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.260706
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 7953/10000 (80%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_37_30_final.pth after epoch 37
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.253142
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.255932
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 8013/10000 (80%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_38_30_final.pth after epoch 38
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.233390
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.264996
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8155/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_39_30_final.pth after epoch 39
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.239716
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.375940
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7754/10000 (78%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_40_30_final.pth after epoch 40
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.207899
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.341458
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7905/10000 (79%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_41_30_final.pth after epoch 41
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.317849
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.286642
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8591/10000 (86%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_42_30_final.pth after epoch 42
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.205430
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.330108
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8344/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_43_30_final.pth after epoch 43
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.298505
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.214063
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8341/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_44_30_final.pth after epoch 44
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.320084
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.315576
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8303/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_45_30_final.pth after epoch 45
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.245524
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.289022
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7802/10000 (78%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_46_30_final.pth after epoch 46
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.342160
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.247366
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8253/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_47_30_final.pth after epoch 47
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.256891
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.211527
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7779/10000 (78%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_48_30_final.pth after epoch 48
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.314861
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.402683
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8515/10000 (85%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_49_30_final.pth after epoch 49
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.268315
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.332853
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8355/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_50_30_final.pth after epoch 50
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 51 [0/50000 (0%)]	Loss: 0.237620
# Train Epoch: 51 [25600/50000 (51%)]	Loss: 0.296543
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8490/10000 (85%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_51_30_final.pth after epoch 51
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 52 [0/50000 (0%)]	Loss: 0.186008
# Train Epoch: 52 [25600/50000 (51%)]	Loss: 0.225756
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8405/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_52_30_final.pth after epoch 52
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 53 [0/50000 (0%)]	Loss: 0.326339
# Train Epoch: 53 [25600/50000 (51%)]	Loss: 0.262107
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8088/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_53_30_final.pth after epoch 53
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 54 [0/50000 (0%)]	Loss: 0.305144
# Train Epoch: 54 [25600/50000 (51%)]	Loss: 0.324297
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7798/10000 (78%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_54_30_final.pth after epoch 54
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 55 [0/50000 (0%)]	Loss: 0.200462
# Train Epoch: 55 [25600/50000 (51%)]	Loss: 0.331320
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8098/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_55_30_final.pth after epoch 55
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 56 [0/50000 (0%)]	Loss: 0.292179
# Train Epoch: 56 [25600/50000 (51%)]	Loss: 0.264730
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7727/10000 (77%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_56_30_final.pth after epoch 56
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 57 [0/50000 (0%)]	Loss: 0.262779
# Train Epoch: 57 [25600/50000 (51%)]	Loss: 0.342832
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7687/10000 (77%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_57_30_final.pth after epoch 57
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 58 [0/50000 (0%)]	Loss: 0.214770
# Train Epoch: 58 [25600/50000 (51%)]	Loss: 0.225987
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 7768/10000 (78%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_58_30_final.pth after epoch 58
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 59 [0/50000 (0%)]	Loss: 0.320910
# Train Epoch: 59 [25600/50000 (51%)]	Loss: 0.347343
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0009, Accuracy: 7489/10000 (75%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_59_30_final.pth after epoch 59
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 60 [0/50000 (0%)]	Loss: 0.266152
# Train Epoch: 60 [25600/50000 (51%)]	Loss: 0.269345
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8415/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_60_30_final.pth after epoch 60
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 61 [0/50000 (0%)]	Loss: 0.172048
# Train Epoch: 61 [25600/50000 (51%)]	Loss: 0.350932
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8322/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_61_30_final.pth after epoch 61
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 62 [0/50000 (0%)]	Loss: 0.267814
# Train Epoch: 62 [25600/50000 (51%)]	Loss: 0.308691
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8045/10000 (80%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_62_30_final.pth after epoch 62
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 63 [0/50000 (0%)]	Loss: 0.247789
# Train Epoch: 63 [25600/50000 (51%)]	Loss: 0.243775
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8526/10000 (85%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_63_30_final.pth after epoch 63
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 64 [0/50000 (0%)]	Loss: 0.252384
# Train Epoch: 64 [25600/50000 (51%)]	Loss: 0.178316
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8377/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_64_30_final.pth after epoch 64
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 65 [0/50000 (0%)]	Loss: 0.250189
# Train Epoch: 65 [25600/50000 (51%)]	Loss: 0.274693
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8063/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_65_30_final.pth after epoch 65
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 66 [0/50000 (0%)]	Loss: 0.291392
# Train Epoch: 66 [25600/50000 (51%)]	Loss: 0.253330
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0007, Accuracy: 8028/10000 (80%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_66_30_final.pth after epoch 66
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 67 [0/50000 (0%)]	Loss: 0.322388
# Train Epoch: 67 [25600/50000 (51%)]	Loss: 0.214936
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8257/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_67_30_final.pth after epoch 67
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 68 [0/50000 (0%)]	Loss: 0.229862
# Train Epoch: 68 [25600/50000 (51%)]	Loss: 0.324697
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8581/10000 (86%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_68_30_final.pth after epoch 68
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 69 [0/50000 (0%)]	Loss: 0.239662
# Train Epoch: 69 [25600/50000 (51%)]	Loss: 0.271174
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8111/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_69_30_final.pth after epoch 69
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 70 [0/50000 (0%)]	Loss: 0.321437
# Train Epoch: 70 [25600/50000 (51%)]	Loss: 0.268985
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8228/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_70_30_final.pth after epoch 70
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 71 [0/50000 (0%)]	Loss: 0.188781
# Train Epoch: 71 [25600/50000 (51%)]	Loss: 0.299124
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8135/10000 (81%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_71_30_final.pth after epoch 71
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 72 [0/50000 (0%)]	Loss: 0.239229
# Train Epoch: 72 [25600/50000 (51%)]	Loss: 0.280526
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8546/10000 (85%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_72_30_final.pth after epoch 72
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 73 [0/50000 (0%)]	Loss: 0.305705
# Train Epoch: 73 [25600/50000 (51%)]	Loss: 0.262134
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8450/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_73_30_final.pth after epoch 73
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 74 [0/50000 (0%)]	Loss: 0.201780
# Train Epoch: 74 [25600/50000 (51%)]	Loss: 0.261941
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8614/10000 (86%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_74_30_final.pth after epoch 74
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 75 [0/50000 (0%)]	Loss: 0.246849
# Train Epoch: 75 [25600/50000 (51%)]	Loss: 0.299646
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0008, Accuracy: 7512/10000 (75%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_75_30_final.pth after epoch 75
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 76 [0/50000 (0%)]	Loss: 0.223015
# Train Epoch: 76 [25600/50000 (51%)]	Loss: 0.247231
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8165/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_76_30_final.pth after epoch 76
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 77 [0/50000 (0%)]	Loss: 0.207571
# Train Epoch: 77 [25600/50000 (51%)]	Loss: 0.161626
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8604/10000 (86%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_77_30_final.pth after epoch 77
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 78 [0/50000 (0%)]	Loss: 0.271132
# Train Epoch: 78 [25600/50000 (51%)]	Loss: 0.240618
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8420/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_78_30_final.pth after epoch 78
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 79 [0/50000 (0%)]	Loss: 0.155747
# Train Epoch: 79 [25600/50000 (51%)]	Loss: 0.247804
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8672/10000 (87%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_79_30_final.pth after epoch 79
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 80 [0/50000 (0%)]	Loss: 0.174904
# Train Epoch: 80 [25600/50000 (51%)]	Loss: 0.263589
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0004, Accuracy: 8607/10000 (86%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_80_30_final.pth after epoch 80
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 81 [0/50000 (0%)]	Loss: 0.307695
# Train Epoch: 81 [25600/50000 (51%)]	Loss: 0.302939
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8296/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_81_30_final.pth after epoch 81
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 82 [0/50000 (0%)]	Loss: 0.177428
# Train Epoch: 82 [25600/50000 (51%)]	Loss: 0.254778
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8352/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_82_30_final.pth after epoch 82
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 83 [0/50000 (0%)]	Loss: 0.238741
# Train Epoch: 83 [25600/50000 (51%)]	Loss: 0.252897
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8275/10000 (83%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_83_30_final.pth after epoch 83
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 84 [0/50000 (0%)]	Loss: 0.208792
# Train Epoch: 84 [25600/50000 (51%)]	Loss: 0.210621
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0005, Accuracy: 8366/10000 (84%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_84_30_final.pth after epoch 84
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 85 [0/50000 (0%)]	Loss: 0.199343
# Train Epoch: 85 [25600/50000 (51%)]	Loss: 0.273761
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0006, Accuracy: 8245/10000 (82%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_85_30_final.pth after epoch 85
#
# ...
# Train Epoch: 166 [25600/50000 (51%)]	Loss: 0.002762
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0003, Accuracy: 9323/10000 (93%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_166_30_final.pth after epoch 166
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 167 [0/50000 (0%)]	Loss: 0.005301
# Train Epoch: 167 [25600/50000 (51%)]	Loss: 0.005003
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0003, Accuracy: 9330/10000 (93%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_167_30_final.pth after epoch 167
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 168 [0/50000 (0%)]	Loss: 0.004616
# Train Epoch: 168 [25600/50000 (51%)]	Loss: 0.001645
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9371/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_168_30_final.pth after epoch 168
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 169 [0/50000 (0%)]	Loss: 0.006262
# Train Epoch: 169 [25600/50000 (51%)]	Loss: 0.016348
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9369/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_169_30_final.pth after epoch 169
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 170 [0/50000 (0%)]	Loss: 0.006706
# Train Epoch: 170 [25600/50000 (51%)]	Loss: 0.002109
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0003, Accuracy: 9369/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_170_30_final.pth after epoch 170
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 171 [0/50000 (0%)]	Loss: 0.004493
# Train Epoch: 171 [25600/50000 (51%)]	Loss: 0.001971
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9374/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_171_30_final.pth after epoch 171
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 172 [0/50000 (0%)]	Loss: 0.008030
# Train Epoch: 172 [25600/50000 (51%)]	Loss: 0.003098
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9369/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_172_30_final.pth after epoch 172
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 173 [0/50000 (0%)]	Loss: 0.003426
# Train Epoch: 173 [25600/50000 (51%)]	Loss: 0.002296
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9366/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_173_30_final.pth after epoch 173
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 174 [0/50000 (0%)]	Loss: 0.001746
# Train Epoch: 174 [25600/50000 (51%)]	Loss: 0.008366
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0003, Accuracy: 9371/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_174_30_final.pth after epoch 174
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 175 [0/50000 (0%)]	Loss: 0.009316
# Train Epoch: 175 [25600/50000 (51%)]	Loss: 0.001975
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9374/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_175_30_final.pth after epoch 175
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 176 [0/50000 (0%)]	Loss: 0.001306
# Train Epoch: 176 [25600/50000 (51%)]	Loss: 0.003593
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9386/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_176_30_final.pth after epoch 176
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 177 [0/50000 (0%)]	Loss: 0.007663
# Train Epoch: 177 [25600/50000 (51%)]	Loss: 0.001692
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9408/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_177_30_final.pth after epoch 177
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 178 [0/50000 (0%)]	Loss: 0.000796
# Train Epoch: 178 [25600/50000 (51%)]	Loss: 0.001595
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9380/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_178_30_final.pth after epoch 178
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 179 [0/50000 (0%)]	Loss: 0.003181
# Train Epoch: 179 [25600/50000 (51%)]	Loss: 0.001566
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9390/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_179_30_final.pth after epoch 179
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 180 [0/50000 (0%)]	Loss: 0.002803
# Train Epoch: 180 [25600/50000 (51%)]	Loss: 0.001385
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9389/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_180_30_final.pth after epoch 180
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 181 [0/50000 (0%)]	Loss: 0.000632
# Train Epoch: 181 [25600/50000 (51%)]	Loss: 0.001321
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9402/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_181_30_final.pth after epoch 181
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 182 [0/50000 (0%)]	Loss: 0.001657
# Train Epoch: 182 [25600/50000 (51%)]	Loss: 0.004333
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9410/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_182_30_final.pth after epoch 182
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 183 [0/50000 (0%)]	Loss: 0.000783
# Train Epoch: 183 [25600/50000 (51%)]	Loss: 0.001437
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9411/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_183_30_final.pth after epoch 183
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 184 [0/50000 (0%)]	Loss: 0.005645
# Train Epoch: 184 [25600/50000 (51%)]	Loss: 0.000895
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9423/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_184_30_final.pth after epoch 184
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 185 [0/50000 (0%)]	Loss: 0.001403
# Train Epoch: 185 [25600/50000 (51%)]	Loss: 0.001409
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9412/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_185_30_final.pth after epoch 185
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 186 [0/50000 (0%)]	Loss: 0.001231
# Train Epoch: 186 [25600/50000 (51%)]	Loss: 0.000638
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9403/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_186_30_final.pth after epoch 186
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 187 [0/50000 (0%)]	Loss: 0.001725
# Train Epoch: 187 [25600/50000 (51%)]	Loss: 0.000769
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9409/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_187_30_final.pth after epoch 187
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 188 [0/50000 (0%)]	Loss: 0.001401
# Train Epoch: 188 [25600/50000 (51%)]	Loss: 0.001020
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9402/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_188_30_final.pth after epoch 188
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 189 [0/50000 (0%)]	Loss: 0.002357
# Train Epoch: 189 [25600/50000 (51%)]	Loss: 0.001185
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9406/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_189_30_final.pth after epoch 189
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 190 [0/50000 (0%)]	Loss: 0.000733
# Train Epoch: 190 [25600/50000 (51%)]	Loss: 0.000708
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9417/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_190_30_final.pth after epoch 190
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 191 [0/50000 (0%)]	Loss: 0.000599
# Train Epoch: 191 [25600/50000 (51%)]	Loss: 0.001367
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9422/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_191_30_final.pth after epoch 191
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 192 [0/50000 (0%)]	Loss: 0.000896
# Train Epoch: 192 [25600/50000 (51%)]	Loss: 0.001039
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9419/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_192_30_final.pth after epoch 192
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 193 [0/50000 (0%)]	Loss: 0.001499
# Train Epoch: 193 [25600/50000 (51%)]	Loss: 0.000643
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9424/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_193_30_final.pth after epoch 193
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 194 [0/50000 (0%)]	Loss: 0.000977
# Train Epoch: 194 [25600/50000 (51%)]	Loss: 0.000902
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9409/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_194_30_final.pth after epoch 194
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 195 [0/50000 (0%)]	Loss: 0.000637
# Train Epoch: 195 [25600/50000 (51%)]	Loss: 0.001159
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9410/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_195_30_final.pth after epoch 195
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 196 [0/50000 (0%)]	Loss: 0.000907
# Train Epoch: 196 [25600/50000 (51%)]	Loss: 0.001371
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9402/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_196_30_final.pth after epoch 196
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 197 [0/50000 (0%)]	Loss: 0.001074
# Train Epoch: 197 [25600/50000 (51%)]	Loss: 0.000849
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9413/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_197_30_final.pth after epoch 197
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 198 [0/50000 (0%)]	Loss: 0.003985
# Train Epoch: 198 [25600/50000 (51%)]	Loss: 0.001696
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9406/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_198_30_final.pth after epoch 198
#
# -------------------------------------
# No weights changed.
# Scores changed!
# Train Epoch: 199 [0/50000 (0%)]	Loss: 0.000818
# Train Epoch: 199 [25600/50000 (51%)]	Loss: 0.001087
# Percentage of weights set to zero: 69.99999152289497%
# Percentage of weights set to one: 30.000008477105034%
# Test set: Average loss: 0.0002, Accuracy: 9417/10000 (94%)
#
# Model saved to /content/drive/My Drive/resnet18_slt_models/init_signed_constant/resnet18_slt_epoch_199_30_final.pth after epoch 199

# %%
check_weights_change(initial_weights, model)
# Out:
# Weihts changed!

# %%
check_scores_change(initial_scores, model)
# Out:
# No scores changed.

# %%
# Move model to the specified device
model.to(device)
model.eval()  # Set the model to evaluation mode

correct = 0
total = 0
with torch.no_grad():  # No need to track gradients
    for data in test_loader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.2f}%')
# Out:
# Accuracy of the network on the 10000 test images: 91.76%
